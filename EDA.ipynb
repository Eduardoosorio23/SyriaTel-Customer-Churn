# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline

# %%
df = pd.read_csv('Data/churm_data.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df = df.drop(['phone number', 'state'], axis=1, inplace=False)

# %%
df.isna().sum()#No Null in this data set
# Out:
# account length            0
# area code                 0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
# account length            3333 non-null int64
# area code                 3333 non-null int64
# international plan        3333 non-null object
# voice mail plan           3333 non-null object
# number vmail messages     3333 non-null int64
# total day minutes         3333 non-null float64
# total day calls           3333 non-null int64
# total day charge          3333 non-null float64
# total eve minutes         3333 non-null float64
# total eve calls           3333 non-null int64
# total eve charge          3333 non-null float64
# total night minutes       3333 non-null float64
# total night calls         3333 non-null int64
# total night charge        3333 non-null float64
# total intl minutes        3333 non-null float64
# total intl calls          3333 non-null int64
# total intl charge         3333 non-null float64
# customer service calls    3333 non-null int64
# ...

# %%
df.shape
# Out:
# (3333, 19)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.histplot(data=df, x="customer service calls", hue="churn", multiple="dodge", shrink=6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-d1fe5b12c0c4> in <module>
#       1 sns.set(rc={'figure.figsize':(11.7,8.27)})
#       2 sns.histplot(data=df, x="customer service calls", hue="churn", multiple="dodge", shrink=6)
# ----> 3 sns.margins()
#
# AttributeError: module 'seaborn' has no attribute 'margins'

# %%
sns.histplot(data=df, x="total day charge", hue="churn", multiple="dodge")

# %%
sns.histplot(data=df, x="international plan", hue="churn", multiple="dodge", shrink = .5)

# %%
sns.histplot(data=df, x="total day minutes", hue="churn", multiple="dodge", shrink = 1)

# %%
g = sns.JointGrid(data=df, x="total day charge", y="customer service calls", hue="churn")
# g.joint_plot(sns.scatterplot, sns.histplot)
g.plot_joint(sns.scatterplot, alpha=.5)
g.plot_marginals(sns.histplot, kde=True)

# %%
h = sns.JointGrid(data=df, x="total day minutes", y="total day calls", hue="churn")
h.plot(sns.scatterplot, sns.histplot)

# %%
j = sns.JointGrid(data=df, x="total night minutes", y="total night calls", hue="churn")
j.plot(sns.scatterplot, sns.histplot)

# %%
df['international plan'] = pd.get_dummies(df['international plan'])
df['voice mail plan'] = pd.get_dummies(df['voice mail plan'])
df['churn'] = pd.get_dummies(df['churn'])
df.head(20)#in the churn column True = 0, False = 1
#in the international plan and voice mail plan columns, yes = 0, no = 1
# Out:
#     account length  area code  international plan  voice mail plan  \
# 0              128        415                   1                0
# 1              107        415                   1                0
# 2              137        415                   1                1
# 3               84        408                   0                1
# 4               75        415                   0                1
# 5              118        510                   0                1
# 6              121        510                   1                0
# 7              147        415                   0                1
# 8              117        408                   1                1
# 9              141        415                   0                0
# 10              65        415                   1                1
# 11              74        415                   1                1
# 12             168        408                   1                1
# ...

# %%
df.head(20)#in the churn column True = 0, False = 1
# Out:
#     account length  area code  international plan  voice mail plan  \
# 0              128        415                   1                0
# 1              107        415                   1                0
# 2              137        415                   1                1
# 3               84        408                   0                1
# 4               75        415                   0                1
# 5              118        510                   0                1
# 6              121        510                   1                0
# 7              147        415                   0                1
# 8              117        408                   1                1
# 9              141        415                   0                0
# 10              65        415                   1                1
# 11              74        415                   1                1
# 12             168        408                   1                1
# ...

# %%
df.shape
# Out:
# (3333, 19)

# %%
df.hist(figsize=(15, 12), bins='auto');

# %%
df.corr()
# Out:
#                         account length  area code  international plan  \
# account length                1.000000  -0.012463           -0.024735
# area code                    -0.012463   1.000000           -0.048551
# international plan           -0.024735  -0.048551            1.000000
# voice mail plan              -0.002918   0.000747            0.006006
# number vmail messages        -0.004628  -0.001994           -0.008745
# total day minutes             0.006216  -0.008264           -0.049396
# total day calls               0.038470  -0.009646           -0.003755
# total day charge              0.006214  -0.008264           -0.049398
# total eve minutes            -0.006757   0.003580           -0.019100
# total eve calls               0.019260  -0.011886           -0.006114
# total eve charge             -0.006745   0.003607           -0.019106
# total night minutes          -0.008955  -0.005825            0.028905
# ...

# %%
df.to_csv(r'Data/churm_data_cleaned.csv', index = False)
